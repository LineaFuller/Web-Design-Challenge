# %%
import pandas as pd

# %%
df = pd.read_csv('WeatherPy.csv')
df.head()
# Out:
#         City      Lat       Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Galesong  -5.3166  119.3661     77.02        80          71        3.69
# 1       Teno -34.8667  -71.1833     74.75        43           0       10.36
# 2     Castro -24.7911  -50.0119     62.13        94           3        9.35
# 3      Igrim  63.1906   64.4162     21.38        74         100       12.91
# 4  Busselton -33.6500  115.3333     53.04        65           0        8.25
#
#   Country        Date
# 0      ID  1636498341
# 1      CL  1636498342
# 2      BR  1636498342
# 3      RU  1636498343
# 4      AU  1636498343

# %%
html_table = df.to_html()

# %%
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lon</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Galesong</td>\n      <td>-5.3166</td>\n      <td>119.3661</td>\n      <td>77.02</td>\n      <td>80</td>\n      <td>71</td>\n      <td>3.69</td>\n      <td>ID</td>\n      <td>1636498341</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Teno</td>\n      <td>-34.8667</td>\n      <td>-71.1833</td>\n      <td>74.75</td>\n      <td>43</td>\n      <td>0</td>\n      <td>10.36</td>\n      <td>CL</td>\n      <td>1636498342</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Castro</td>\n      <td>-24.7911</td>\n      <td>-50.0119</td>\n      <td>62.13</td>\n      <td>94</td>\n      <td>3</td>\n      <td>9.3
# ...

# %%
df.to_html('data.html')
